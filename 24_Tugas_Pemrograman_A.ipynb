# %%
# Mengimpor modul yang diperlukan
from main import main
# Atau mengimpor fungsi-fungsi spesifik jika diperlukan
from data_loader import load_data
from population_model import train_population_model

# Menjalankan fungsi utama
main()
# Out:
# Data head:
#    Year  Percentage_Internet_User  Population
# 0  1960                       0.0    88296070
# 1  1961                       0.0    90791249
# 2  1962                       0.0    93375850
# 3  1963                       0.0    96051424
# 4  1964                       0.0    98833749
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      60 non-null     int64
#  1   Percentage_Internet_User  60 non-null     float64
#  2   Population                60 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 1.5 KB
# None
#
# Data description:
#               Year  Percentage_Internet_User    Population
# count    60.000000                 60.000000  6.000000e+01
# mean   1990.233333                  7.882100  1.825028e+08
# std      18.502741                 17.612836  5.910061e+07
# min    1960.000000                  0.000000  8.829607e+07
# 25%    1974.750000                  0.000000  1.310216e+08
# 50%    1989.500000                  0.000000  1.818514e+08
# 75%    2004.750000                  3.396785  2.302106e+08
# max    2023.000000                 69.208400  2.811901e+08
#
# Missing values:
# Year                        0
# Percentage_Internet_User    0
# Population                  0
# dtype: int64
# Years with missing values:
# Series([], Name: Year, dtype: int64)
# Degree 2: R² = 0.9992291899369616
# Degree 3: R² = 0.999878721246272
# Degree 4: R² = 0.9998763139227992
# Degree 5: R² = 0.9998738888222108
# Best polynomial degree for population: 3 with R² = 0.999878721246272
# Population polynomial equation:
# y = 2346982050090.58 - 3549267692.848241x^1 + 1787567.680112x^2 - 299.812658x^3
# Logistic model parameters: L=100.00, k=0.2493, x0=2019.48
# Internet percentage logistic equation:
# y = 100.00 / (1 + exp(-0.249287 * (x - 2019.48)))
# R² for internet logistic model: 0.9971
# Estimated Missing Values:
#    Year  Estimated_Population  Estimated_Internet_Percentage
# 0  2005          2.320583e+08                       2.637521
# 1  2006          2.351577e+08                       3.359146
# 2  2015          2.613336e+08                      24.680342
# 3  2016          2.640180e+08                      29.599407
#
# Predictions for Years 2030 and 2035:
#    Year  Predicted_Population  Predicted_Internet_Percentage  \
# 0  2030          2.953844e+08                      93.236299
# 1  2035          3.032054e+08                      97.956783
#
#    Predicted_Internet_Users
# 0              2.754055e+08
# 1              2.970103e+08
# ANALYSIS SUMMARY:
# ==========================
# 1. Population Model: Polynomial degree 3 (R² = 0.9999)
#    Equation: y = 2346982050090.58 - 3549267692.848241x^1 + 1787567.680112x^2 - 299.812658x^3
# 2. Internet Model: Logistic (R² = 0.9971)
#    Equation: y = 100.00 / (1 + exp(-0.249287 * (x - 2019.48)))
#
# Missing Value Estimates:
#    2005: Population = 232,058,282, Internet = 2.64%
#    2006: Population = 235,157,743, Internet = 3.36%
#    2015: Population = 261,333,583, Internet = 24.68%
#    2016: Population = 264,017,996, Internet = 29.60%
#
# Future Predictions:
#    2030: Population = 295,384,447, Internet = 93.24%, Users = 275,405,528
#    2035: Population = 303,205,407, Internet = 97.96%, Users = 297,010,262
